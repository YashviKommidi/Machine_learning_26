# %% [markdown]
# ## Course Information
# INFO 521: Introduction to Machine Learning\
# Instructor: Xuan Lu, College of Information Science

# %% [markdown]
# ## Instructions
# #### Objectives
# This worksheet will assess your knowledge of basic commands in Python. Please review the lectures, suggested readings, and additional resources before starting the homework, as this document closely follows the provided materials.
#
# #### Grading
# Please note that grades are **NOT exclusively based on your final answers**. We will be grading the overall structure and logic of your code. Feel free to use as many lines as you need to answer each of the questions. I also highly recommend and strongly encourage adding comments (`#`) to your code. Comments will certainly improve the reproducibility and readability of your submission. Commenting your code is also good coding practice. **Specifically for the course, you’ll get better feedback if the TA is able to understand your code in detail.**
#
# __Total score__: 100 points, with 20 points for Questions 1-3 and 80 points for the brief independent project.
#
# #### Submission
# This homework is due by the end of **April 21** (**Tuesday, 11:59 pm AZ time**). Please contact the instructor if you are (i) having issues opening the assignment, (ii) not understanding the questions, or (iii) having issues submitting your assignment. Note that late submissions are subject to a penalty (see late work policies in the syllabus).
# - Please submit a single Jupyter Notebook file (this file). Answers to each question should be included in the relevant block of code (see below). Rename your file to "**lastname_Hw7.ipynb**" before submitting. If a given block of code is causing issues and you didn't manage to fix it, please add comments.
#
# #### Time commitment
# Please reach out if you’re taking more than ~18h to complete (1) this homework, (2) reading the book chapters, and (3) going over the lectures. I will be happy to provide accommodations if necessary. **Do not wait until the last minute to start working on this homework**. In most cases, working under pressure will certainly increase the time needed to answer each of these questions and the instructor and the TA might not be 100% available on Sundays to troubleshoot with you.
#
# #### Looking for help?
# First, please go over the relevant readings for this week. Second, if you’re still struggling with any of the questions, do some independent research (e.g. stackoverflow is a wonderful resource). Don’t forget that your classmates will also be working on the same questions - reach out for help (check under the Discussion forum for folks looking to interact with other students in this class or start your own thread). Finally, the TA is available to answer any questions during office hours and via email.

# %% [markdown]
# ## Questions
# #### Author:
# Name: Yashvi Kommidi\
# Affiliation:  MSDS student at College of Information Science

# %% [markdown]
# ### Conceptual

# %% [markdown]
# #### Question 1
#
# Draw an example (of your own invention) of a partition of two-dimensional feature space that could result from recursive binary splitting. Your example should contain at least eight regions. Draw a decision tree corresponding to this partition. Be sure to label all aspects of your figures, including the regions $R_1$, $R_2$, ... , the cutpoints $t_1$ , $t_2$, ..., and so forth. Please insert your sketch below and make sure the sketch file is attached to your submission.

# %% [markdown]
#   > **_Answer:_**
#   ![image.png](attachment:image.png)
#
# I have performed  7 recursive binary splits which are in order of t1, t2, t3, t4, t5, t6, t7
#
# and firstly
#
# t1 has vertical split the space into 2 parts which is left and right
#
# then t2 has horizontal split the left part into top left and bottom left
#
# now t3 has split the top left into two parts with vertical cut into R1 and R2
#
# t4 has horizontal split the right part to top right and bottom right
#
# now t5 has horizontal split the top right into R3 and R4
#
# t6 has split the bottom right with vertical cut into R5 and R6
#
# and at last t7 has horizontal cut the left bottom into R7 and R8
#
# if we look at the decision tree if the X1 value is less than t1, then its a yes condition and we proceed to X2 < t2 condition, and when X1 is higher than t1, then its a no case and we go to right side to X2 < t4 side if X2 < t2 then we go to yes side which is X2 < t7 and if its no, then we go right side which is X1< t3 side. if X2< t4, then we go yes side of X1< t6 and if its no then we go to X2< t5 If X2 < t7 then its R7 and if X2> t7 then R8 if X1< t3 then its R1 and if X1>t3 then R2 if X1< t6 then R5 and if X1>t6 then R6 if X2< t5 then R3 and if X2>t5 then R4

# %% [markdown]
# #### Question 2
#
# Suppose we produce ten bootstrapped samples from a data set containing red and green classes. We then apply a classification tree to each bootstrapped sample and, for a specific value of $X$, produce $10$ estimates of $P(Class is Red|X)$:
#
# $0.1$, $0.15$, $0.2$, $0.2$, $0.55$, $0.6$, $0.6$, $0.65$, $0.7$, and $0.75$.
#
# There are two common ways to combine these results together into a single class prediction. One is the majority vote approach discussed in this week's lecture and readings. The second approach is to classify based on the average probability. In this example, what is the final classification under each of these two approaches?

# %% [markdown]
#   > **_Answer:_** here according to the question we have 10 trees, that is a classification tree has been applied to each of bootstrapped sample and the values of $P(Class is Red|X)$ were given. And there are two common ways to combine these results together into a single class prediction, out of these one is the majority vote approach and the second approach is to classify based on the average probability.
#
#
#
# > here we are calculating the $P(Class is Red|X)$, so if probability is greater than 0.5 then its more likely to be red which means we can classify it as red and similarly if the probability is less  than 0.5 its green and can be classified as green.
#
#
#
# > first method is majority vote approach where whichever outcome green or red has high votes, then it would be the final prediction.
#
# >lets see what would be for each tree, 0.1 is green, 0.15 is green, 0.2 is green, 0.2 is green, 0.55 is red, 0.6 is red, 0.6 is red,  0.65 is red, 0.7 is red and 0.75 is red , which gives us 4 green and 6 red votes. So here the final prediction will be RED.
#
#
# > next method is average probability approach, where we will calculate the average of all the 10 trees probabilities and if the average probability is less than 0.5 then its green and if its greater than 0.5 its red.
#
# > (0.1 + 0.15 + 0.2 + 0.2 + 0.55 + 0.6 + 0.6 + 0.65 + 0.7 + 0.75) / 10
#
# > = 4.5/10
#
# > 0.45
#
# > so the calculated average probability is 0.45 which means its less than 0.5 so the final prediction will be GREEN.
#
#
#
# >The above 2 approaches has given us 2 different answers such as the majority votes method says its RED and average probability says GREEN. this difference actually would happen because of taking the values into consideration, first one takes individually and the second one takes it combinely, as few of them are low the whole average came down.

# %% [markdown]
# ## Applied

# %% [markdown]
# #### Question 3
#
# Apply boosting and random forest to a data set of your choice. Feel free to use any of the datasets in the `ISLP` python package (e.g. `College`) to examine any of the questions that were discussed in any of the previous homeworks. See https://intro-stat-learning.github.io/ISLP/data.html for `ISLP` datasets. Be sure to fit the models on a training set and to evaluate their performance on a test set. How accurate are the results compared to simple methods (e.g. linear or logistic regression models)? Which of these approaches yields the best performance?

# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt


#loading the college dataset
college_data = pd.read_csv('College.csv')

#dropping the college name column
college_data = college_data.drop(columns=['Unnamed: 0'])

#converting the Private column to 0 and 1 as it is categorical
college_data['Private'] = LabelEncoder().fit_transform(college_data['Private'])

#checking if there are any missing values
print("missing values:", college_data.isnull().sum().sum())

#separating the features and target
X = college_data.drop(columns=['Outstate'])
y = college_data['Outstate']

# splitting the data into into train and test (70/30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# code for linear regression
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)
print("\nlinear regression")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, lr_preds)):.2f}")
print(f"R2: {r2_score(y_test, lr_preds):.3f}")

#code for random forest model
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)
print("\nrandom forest")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, rf_preds)):.2f}")
print(f"R2: {r2_score(y_test, rf_preds):.3f}")

#code for boosting method 
gb = GradientBoostingRegressor(random_state=42)
gb.fit(X_train, y_train)
gb_preds = gb.predict(X_test)
print("\ngradient boosting")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, gb_preds)):.2f}")
print(f"R2: {r2_score(y_test, gb_preds):.3f}")

#comparing all the three models using a line graph
models = ['linear regression', 'random forest', 'gradient boosting']
rmse_scores = [
    np.sqrt(mean_squared_error(y_test, lr_preds)),
    np.sqrt(mean_squared_error(y_test, rf_preds)),
    np.sqrt(mean_squared_error(y_test, gb_preds))
]
r2_scores = [
    r2_score(y_test, lr_preds),
    r2_score(y_test, rf_preds),
    r2_score(y_test, gb_preds)
]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

#plot for RMSE comparison
axes[0].plot(models, rmse_scores, marker='o', color='steelblue', linewidth=2)
axes[0].set_title('RMSE Comparison (lower is better)')
axes[0].set_ylabel('RMSE')

# plot for R2 comparison 
axes[1].plot(models, r2_scores, marker='o', color='tomato', linewidth=2)
axes[1].set_title('R² Comparison (higher is better)')
axes[1].set_ylabel('R²')

plt.tight_layout()
plt.show()
# Out:
# missing values: 0
#
# linear regression
# RMSE: 1951.87
# R2: 0.761
#
# random forest
# RMSE: 1853.65
# R2: 0.784
#
# gradient boosting
# RMSE: 1894.21
# R2: 0.775

# %% [markdown]
# for this question I have considered HW6 question which is using the college dataset, predicting the out of state tuition fee with all other variables as predictors and I have applied boosting and random forest models and compared them to simple linear regression model.
#
# Within the process, I noticed through results that there are no missing values in the dataset and the linear regression has the highest RMSE which is 1951. 87  and the lowest R² values which 0.761 which is making the linear regression model the weakest model.  Next I have performed the random forest model and boosting , where RMSE of random forest is 1853.65 and R² value is 0.784 and on the other side, the gradient boosting model has the RMSE value of 1894.21 and the R² value of 0.775.  By looking at the results we can say that the Random forest method has performed well with the lowest RMSE and the highest R² value where as the gradient boosting comes at second by being better than the linear regression but slightly bad than the random forest. we know that when the RMSE value is lower, then the model is better and when the R² value is higher, then the model is better.
#
# We can conclude that in this case with this datase, random forest model yields the best performance compared to the other two models of boosting and simple linear regression.

# %% [markdown]
# ## Brief independent project

# %% [markdown]
# In this part of the assignment, you will be provided with two options of basic ML code used to examine a given question. __Assume that this code was sent to you by a collaborator who is asking for your help in improving their ML workflow.__
#
# 1. Critically examine the steps outlined by your collaborator (e.g. data pre-processing, model development) with the goal of improving the performance of the model given the specific research question.
# 2. Reconsider and re-evaluate their data pre-processing steps.
# 3. Generate an alternative model. Your alternative model can be of the same class as the baseline model (but not necessarily).
# 4. Finally, you will compare your new model to the one suggested by your collaborator. If your model does not outperform your collaborator's model, briefly examine why this was the case.
#
# __Please justify your decisions.__ For instance, explain why you decided to plot Y vs X and not Y vs Z; why 20% of observations in the F feature were inputted using mean values; why model N was selected and not M; or even why model performance is solely examined based on accuracy.
#
# __I’m looking for systematic and well-justified decisions.__ I am interested in reading thoughtful discussions on the potential practical consequences of your decisions. Hint: Assume that you’re explaining this to your collaborator. __Please be brief and focus on your major decisions__. Your grade will be based on your ability to explain your choices and not the length of your submission. Please do not forget to annotate your code.
#
# Your submission (also part of this file; see below) should include only the following sections (also below under __Report__):
#
# ##### Synopsis
# A brief (<300 words) description of the dataset, goals of the analysis, methods used, main results, and conclusions.
#
# ##### Data pre-processing
# Steps related to missing data, reduction of dimensionality, training and test data splits, center, scale, creating dummy variables, etc.
#
# ##### Data exploration
# Correlation analyses, scatterplots, class imbalance, etc.
#
# ##### Model development
# This component should include descriptions on why a given model was used, how each of the examined models was designed (e.g. are you using all the features in the dataset?), tuning (if needed), and model evaluation.
#
# ##### Conclusions
# Frame your conclusions in two different ways (<300 words). First, conclude on the question that is being addressed in your selected project. Second, compare the performance of your approach in relation to your collaborator's model.
#
#
# Choose one of the two options below.

# %% [markdown]
# __Option 1__. Your collaborator is interested in implementing a new model to classify patients into sick or not sick categories. _They are particularly concerned with the number of times their model fails to correctly classify truly sick patients._ Feel free to use any of the variables in the dataset, reconsider the data pre-processing approach, explore other models, data partitions, etc.

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix

Data1Raw = pd.read_csv('sick.data', sep = '\t')
Data1 = Data1Raw.drop(columns=['TBG', 'TBG_measured', 'hypopituitary', 'TSH', 'T3', 'TT4', 'T4U', 'FTI']).dropna()
Data1['Class'] = Data1['Class'].map({'sick': 1, 'negative': 0})

binary_cols = Data1.columns[Data1.isin(['f', 't']).all()]
Data1[binary_cols] = Data1[binary_cols].map(lambda x: 1 if x == 't' else 0)
Data1['sex'] = Data1['sex'].map({'F': 0, 'M': 1})
Data1 = pd.get_dummies(Data1, columns=['referral_source'], dtype='int')

X = Data1.drop(columns=['Class'])
y = Data1['Class']
X = sm.add_constant(X)
glm_model = sm.GLM(y, X, family=sm.families.Binomial())
glm_results = glm_model.fit()

y_pred = glm_results.predict(X)
y_pred_class = [1 if p > 0.5 else 0 for p in y_pred]
conf_matrix = confusion_matrix(y, y_pred_class)
print(conf_matrix)
# Out:
# [[2615  781]
#  [  42  183]]
# /Users/yashvikommidi/Library/Python/3.9/lib/python/site-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)

# %% [markdown]
# __Option 2__. Your collaborator is generating a model to predict the duration of flight delays (`dep_delay`+`arr_delay` in the `flights` dataset). _They will be only convinced that your model is better if you are able to reduce uncertainty around predictions for a novel observation (`newObs`)._ Feel free to use any of the variables in the dataset, reconsider the data pre-processing approach, explore other models, data partitions, etc.
# Hint: Consider the trade-offs associated with the overall model error and prediction error for a particular observation. Consider explaining this to your collaborator.

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

flights = pd.read_csv("flights.data", sep = '\t')
flights['delay'] = flights['dep_delay'] + flights['arr_delay']
flights = flights.loc[flights.delay.notna()]

new_obs = flights.sample(n=1,random_state=5)

flights_train, flights_test = train_test_split(flights, test_size=0.25, random_state=5)
X_train = sm.add_constant(flights_train['distance'])
y_train = flights_train['delay']
de_model = sm.OLS(y_train, X_train).fit()

X_new_obs = sm.add_constant(new_obs[['distance']], has_constant='add')
pred = de_model.get_prediction(X_new_obs)
pred_summary = pred.summary_frame(alpha=0.05)
print(pred_summary)

# %% [markdown]
# ### Report
#
# ##### Synopsis

# %% [markdown]
#   > **_Answer:_** The dataset here we are using is the sick data which has 3772 patient records related to thyroid disease with 30 columns of patient information such as age, sex, symptoms like tumor, thyroid hormone measurements like TSH, T3, TT4, T4U and FTI. Here the target column is class which tells us whether a patient is sick or not. The main goal of this analysis is to correctly classify patients as sick or not while making sure we dont miss any sick patients as wrongly saying they are not sick.
#
#   > When we look at the code that was given, I noticed there are several issues like it dropped hormone features which are important, also did not split the data into train and test sets and also didnt handle the severe class imbalance of only 6% sick patients.  To improve the code, firstly I have kept all the hormone features, and also imputed missing values using median, split the data into 80-20 ratio of train and test and scaled the features and also handled the imbalance.
#
#   > The model I have used is Random forest, as it handles complex relationships between hormone features better than the previous model. I have checked the original code's recall, it is only 0.813 and also had 781 false alarms. Where as the model which I used correctly identified 45 out of 46 sick patients with a recall of 0.978 and only 4 false alarms were there with an overall accuracy of 99%. This helps us to understand that keeping the hormone features and properly preparing the data made a huge difference in the model's ability to identify the sick patients.

# %% [markdown]
# ##### Data pre-processing

# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

#loading the sick data set 
sick_rawdata = pd.read_csv('sick.data', sep='\t')
print(sick_rawdata.shape)
print(sick_rawdata['Class'].value_counts())

# dropping the columns TBG, TBG_measured, and hypopituitary
# dropping TBG becuase the values are 100% missing 
# dropping TBG_measured because all the values are always f
# dropping hypopituitary because the values has 3771 f and 1 t
sick_data = sick_rawdata.drop(columns=['TBG', 'TBG_measured', 'hypopituitary'])

#adding the filter for age as more than 120 would be practically impossible
sick_data = sick_data[sick_data['age'] <= 120]

# encoding the target 
sick_data['Class'] = sick_data['Class'].map({'sick': 1, 'negative': 0})

#encoding binary t/f columns to 1/0
binary_cols = [col for col in sick_data.columns if set(sick_data[col].dropna().unique()).issubset({'t', 'f'})]
for col in binary_cols:
    sick_data[col] = sick_data[col].map({'t': 1, 'f': 0})

# encoding the sex column
#imputing the 150 missing sex values with mode which is the most frequent = F before encoding
sick_data['sex'] = sick_data['sex'].fillna('F')
sick_data['sex'] = sick_data['sex'].map({'F': 0, 'M': 1})

# converting the categories into numbers so the model can understand them
sick_data = pd.get_dummies(sick_data, columns=['referral_source'], drop_first=True, dtype=int)

#separating the features and target
X = sick_data.drop(columns=['Class'])
y = sick_data['Class']

# imputing the missing values with median
imputer = SimpleImputer(strategy='median')
X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

# splitting the data into Train and test
X_train, X_test, y_train, y_test = train_test_split( X_imputed, y, test_size=0.2, random_state=42, stratify=y )

#scaling the features

#  fixing  the overflow warning seen in the collaborator's code
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

#printing results
print(f"Train: {X_train.shape[0]} rows | Test: {X_test.shape[0]} rows")
# Out:
# (3772, 30)
# Class
# negative    3541
# sick         231
# Name: count, dtype: int64
# Train: 3016 rows | Test: 754 rows

# %% [markdown]
# ##### Data exploration

# %%
#importing libraries
import matplotlib.pyplot as plt
import seaborn as sns

# creating a plot for the class imbalances in the data
sick_data['Class'].value_counts().plot(kind='bar', color=['steelblue', 'tomato'])
plt.title('class distribution')
plt.xlabel('Class (0=Negative, 1=Sick)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

#creating plot with TSH by class 
# considering TSH as it is the main thyroid hormone marker
#this helps us see if TSH differs between sick and negative patients
sick_data.boxplot(column='TSH', by='Class', figsize=(6,4))
plt.ylim(0, 30)  # add this line to zoom in
plt.title('TSH by class')
plt.suptitle('')
plt.xlabel('Class (0=Negative, 1=Sick)')
plt.ylabel('TSH Level')
plt.show()

#creating a correlation heatmap
#only using hormone columns as including all features makes the heatmap messy
hormone_cols = ['TSH', 'T3', 'TT4', 'T4U', 'FTI', 'age']
plt.figure(figsize=(7, 5))
sns.heatmap(sick_data[hormone_cols].corr(), cmap='coolwarm', annot=True, fmt='.2f', linewidths=0.5)
plt.title('correlation heatmap of the hormone features')
plt.show()

#checking which columns have missing values
missing = sick_rawdata.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
missing.plot(kind='bar', color='steelblue')
plt.title('missing values per column')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# when we look at the class distribution plot, we can see that the data is heavily imbalanced with around 3500 negative patients and only 231 sick patients which means that the model could easily just predict everyone as negative and still be mostly right, so we can say we need to handle this case. Next looking at the TSH by Class plot, we can say that both the sick and negative patients have similar median TSH levels by sick patients tend to have more extreme high values. This can confirm us that the TSH is useful for identifying the sick patients and justifies keeping it in the model. Next while looking at the correlation heatmap TT4 and FTI shows the highest correlation at 0.79 which generally makes sense because both of these only measure the thyroid hormone levels. As each feature has its own importance, I tried to include all of them. Finally I have used the missing values to see which has the highest missing values and we can say that the TBG has the most missing values which is almost the entire column is empty which is why I have dropped it. We can also see that the other columns like T3, TSH and FTI also have few missing values.

# %% [markdown]
# ##### Model development

# %%
#collaborator's code
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix, recall_score

Data1Raw = pd.read_csv('sick.data', sep = '\t')
Data1 = Data1Raw.drop(columns=['TBG', 'TBG_measured', 'hypopituitary', 'TSH', 'T3', 'TT4', 'T4U', 'FTI']).dropna()
Data1['Class'] = Data1['Class'].map({'sick': 1, 'negative': 0})

binary_cols = Data1.columns[Data1.isin(['f', 't']).all()]
Data1[binary_cols] = Data1[binary_cols].map(lambda x: 1 if x == 't' else 0)
Data1['sex'] = Data1['sex'].map({'F': 0, 'M': 1})
Data1 = pd.get_dummies(Data1, columns=['referral_source'], dtype='int')

X = Data1.drop(columns=['Class'])
y = Data1['Class']
X = sm.add_constant(X)
glm_model = sm.GLM(y, X, family=sm.families.Binomial())
glm_results = glm_model.fit()

y_pred = glm_results.predict(X)
y_pred_class = [1 if p > 0.5 else 0 for p in y_pred]
conf_matrix = confusion_matrix(y, y_pred_class)
print("collaborator's original results")
print(conf_matrix)
print(f"Recall: {recall_score(y, y_pred_class):.3f}")
# Out:
# collaborator's original results
# [[2615  781]
#  [  42  183]]
# Recall: 0.813
# /Users/yashvikommidi/Library/Python/3.9/lib/python/site-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)

# %%
#importing libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, recall_score, classification_report

# the model i am using is Random Forest
# using random forest because it handles complex relationships between hormone features better than logistic regression
rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train_scaled, y_train)

# using threshold of 0.3 to catch more sick patients
rf_probs = rf_model.predict_proba(X_test_scaled)[:, 1]
rf_preds = (rf_probs >= 0.3).astype(int)

print("random forest results are")
print(confusion_matrix(y_test, rf_preds))
print(classification_report(y_test, rf_preds))
print(f"Recall: {recall_score(y_test, rf_preds):.3f}")

# comparing collaborator's model vs our random forest
models = ['collaborator', 'random forest']
recalls = [0.813, recall_score(y_test, rf_preds)]

plt.bar(models, recalls, color=['tomato', 'steelblue'])
plt.title('recall comparison')
plt.ylabel('recall score')
plt.ylim(0.7, 1.0)
plt.show()
# Out:
# random forest results are
# [[704   4]
#  [  1  45]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       708
#            1       0.92      0.98      0.95        46
#
#     accuracy                           0.99       754
#    macro avg       0.96      0.99      0.97       754
# weighted avg       0.99      0.99      0.99       754
#
# Recall: 0.978

# %% [markdown]
# firstly looking at the collaborator's code results , we can see that it only caught 183 out of 225 sick patients with a recall of 0.813 and flagged 781 healthy patients as sick which is a lot of false alarms and we can also see that the overflow warning which is because the features were not scaled. When it comes to the random forest code which i wrote, in the results we can see that it correctly identified 45 out of 46 sick patients with a recall of 0.978 and only flagged 4 healthy patients as sick and also the overall accuracy was around 99% which is huge improvement over the code we had previously.  With the help of a plot I produced, recall comparison is done which shows the difference between both the models.

# %% [markdown]
# ##### Conclusions

# %% [markdown]
#   > **_Answer:_** The main goal of the project was to classify the patients as sick or not while making sure we are not missing any truly sick patients.  The random forest model has correctly identified 45 out of 46 sick patients with a recall of 0.978 which means we can say that the model is barely missing any sick patients and also it has high accuracy of 99%.
#
# > If we look at the collaborator's code and their approach, and also the random forest model, we can say there is a huge improvement in the performance. As the previous code had several issues like dropping important hormone features , not splitting the data into train and test sets and not handling the class imbalance. This previous code also has only recall of 0.813 with 781 false alarms which is bad. After noting down the issues and worked on it with the random forest model, I have achieved a recall of 0.978 for random forest model with only 4 false alarms and also accuracy of 99%. I would say this was possible as I haven't dropped the features and handled the class imbalance.
